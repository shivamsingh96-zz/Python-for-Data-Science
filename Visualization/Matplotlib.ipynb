# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## Simple Examples

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
##plotting using matplotlib 

##plt scatter

plt.scatter(x,y,c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')

# %%
## plt plot

plt.plot(x,y,'r*',linestyle='dashed',linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2d Diagram')
# Out:
# Text(0.5, 1.0, '2d Diagram')

# %%
## Creating Subplots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')
plt.subplot(2,2,4)
plt.plot(x,y,'go')

# %%
x = np.arange(1,11) 
y = 3 * x + 5 
plt.title("Matplotlib demo") 
plt.xlabel("x axis caption") 
plt.ylabel("y axis caption") 
plt.plot(x,y) 
plt.show()

# %%
# loading dataset
data = pd.read_csv("iris.csv")

# %%
data.head()
# Out:
#    sepal length in cm  sepal width in cm  petal length in cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    petal width in cm      outputs
# 0                0.2  Iris-setosa
# 1                0.2  Iris-setosa
# 2                0.2  Iris-setosa
# 3                0.2  Iris-setosa
# 4                0.2  Iris-setosa

# %%
data.columns
# Out:
# Index(['sepal length in cm', 'sepal width in cm', 'petal length in cm',
#        'petal width in cm', 'outputs'],
#       dtype='object')

# %%
data['outputs'].value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: outputs, dtype: int64

# %%
data.plot(kind = 'scatter', x = 'sepal length in cm', y = 'sepal width in cm')

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.FacetGrid(data, hue='outputs', size=6).map(plt.scatter, 'sepal length in cm', 'sepal width in cm').add_legend()

# %%
sns.pairplot(data,hue="outputs",size=3)
# Out:
# C:\Users\SHIVAM SINGH\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(data, hue = 'outputs', size = 5).map(sns.distplot, "petal length in cm").add_legend();
plt.show()
# Out:
# C:\Users\SHIVAM SINGH\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(data, hue = 'outputs', size = 5).map(sns.distplot, "petal width in cm").add_legend();
plt.show()

sns.FacetGrid(data, hue = 'outputs', size = 5).map(sns.distplot, "sepal length in cm").add_legend();
plt.show()

sns.FacetGrid(data, hue = 'outputs', size = 5).map(sns.distplot, "sepal length in cm").add_legend();
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e16f3dedd4ed> in <module>
#       1 ## Simple Examples
#       2
# ----> 3 x=np.arange(0,10)
#       4 y=np.arange(11,21)
#
# NameError: name 'np' is not defined
